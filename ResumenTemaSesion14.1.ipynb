# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernando0828/INTELIGENCIA-ARTIFICIAL-2/blob/main/ResumenTemaSesion14.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reducción de Dimensionalidad**
#
#
# * **01 - Maldición Dimensionalidad**: Introduce el problema fundamental que surge al trabajar con conjuntos de datos que tienen una gran cantidad de características (*features*). Explica cómo el aumento exponencial del volumen del espacio de características vuelve los datos escasos, dificulta el entrenamiento, aumenta el costo computacional y eleva drásticamente el riesgo de sobreajuste.
#
#
# * **02 - Proyección y Variedades**: Explora los dos enfoques principales teóricos para reducir dimensiones. Cubre la técnica de proyectar puntos de datos en subespacios de menor dimensión, así como el modelado de variedades (*Manifold Learning*), que se utiliza para "desenrollar" o aplanar conjuntos de datos que forman estructuras complejas y retorcidas en espacios de alta dimensión.
#
#
# * **03 - Tutorial Técnico PCA**: Profundiza en el Análisis de Componentes Principales (PCA), la técnica lineal más popular. Detalla cómo el algoritmo identifica los ejes ortogonales (componentes principales) que logran capturar y preservar la mayor cantidad de varianza posible al comprimir los datos.
#
#
# * **04 - Optimizando PCA**: Aborda variantes avanzadas para resolver las limitaciones computacionales del PCA tradicional. Incluye métodos para acelerar el procesamiento de grandes volúmenes de datos (como *Randomized PCA*) y técnicas para procesar *datasets* que no caben en la memoria RAM entrenando por lotes (como *Incremental PCA*).
#
#
# * **05 - LLE y Otras Técnicas**: Introduce el *Locally Linear Embedding* (LLE), un potente algoritmo no lineal que reduce la dimensionalidad asegurándose de medir y preservar las distancias locales de cada instancia con sus vecinos más cercanos. También da paso al estudio de otros algoritmos especializados para estructuras topológicas complejas.
