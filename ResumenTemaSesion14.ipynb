# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernando0828/INTELIGENCIA-ARTIFICIAL-2/blob/main/ResumenTemaSesion14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * **01 - Intro a conjuntos**: Establece los fundamentos teóricos sobre cómo la combinación de múltiples algoritmos de aprendizaje (predictores base) permite obtener un meta-modelo con mayor rendimiento predictivo, estabilidad y menor tendencia al sobreajuste que los modelos individuales.
#
#
# * **02 - Clasificadores votación**: Profundiza en la técnica de combinar diferentes clasificadores independientes entrenados sobre el mismo conjunto de datos. Analiza la toma de decisiones por mayoría (votación dura) y mediante el promedio de las probabilidades estimadas (votación suave).
#
#
# * **03 - Bagging, Pasting y OOB**: Explora las técnicas de muestreo de datos para diversificar modelos. Incluye el *Bootstrap Aggregating* o Bagging (muestreo con reemplazo), Pasting (muestreo sin reemplazo) y la validación *Out-of-Bag* (OOB), la cual aprovecha los datos no seleccionados durante el muestreo para evaluar el modelo directamente.
#
#
# * **04 - Bosques Aleatorios**: Analiza esta potente extensión del *Bagging* aplicada específicamente a árboles de decisión. Explica cómo la inyección de aleatoriedad en la selección de características (*features*) en cada división de nodo genera árboles descorrelacionados y mejora la capacidad de generalización.
#
#
# * **05 - Algoritmos de Boosting**: Introduce los métodos de ensamblaje secuencial (como AdaBoost o Gradient Boosting), donde cada modelo sucesivo se entrena con el objetivo de enfocarse en las instancias mal clasificadas y corregir los errores residuales de sus predecesores.
#
#
# * **06 - Stacking**: Aborda la generalización apilada, un método avanzado donde en lugar de usar funciones predefinidas (como la media o la votación) para agregar predicciones, se entrena un algoritmo final (meta-aprendiz) encargado de recibir las salidas de los modelos base y combinarlas de la forma más óptima posible.
